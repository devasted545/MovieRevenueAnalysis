# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv("imdb_movies_cleaned.csv")

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mssql+pyodbc://DEVANSH-LAPTOP\\SQLEXPRESS/moviereviewanalysis"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
df.to_sql(
    name='Movies',
    con=engine,
    if_exists='append',
    index=False
)
# Out:
# 197
